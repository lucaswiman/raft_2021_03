# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Keith Lazuka: remote from Ohio (I think?). Also came up with the idea of using a state machine. Wrote impl in ruby.
#
# Aniruddha Atale: in SF (I think?).

# %% [markdown]
# **Day 1 HW:** look at the raft paper again, especially focusing on section 5.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# TODO: finish this spec:
# ```tla
# ------------------------------ MODULE traffic ------------------------------
# EXTENDS Integers
#
# \* This is a comment
# VARIABLES ew, ns, clock, button
#
# Init == /\ ew = "G"
#         /\ ns = "R"
#         /\ clock = 0
#         /\ button = FALSE
#
# ClockTick == \/ /\ ew = "G"
#                 /\ ns = "R"
#                 /\ clock = 29
#                 /\ ew' = "Y"
#                 /\ clock' = 0
#                 /\ UNCHANGED <<ns, button>>
# \*             \/ /\ ew = "Y"
# \*                /\ ns = "R"
#
#
#
# ButtonPress == /\ button = FALSE
#                /\ button' = TRUE
#                /\ UNCHANGED <<ew, ns, clock>>
#
#
# Next == ClockTick \/ ButtonPress
#
# =============================================================================
# \* Modification History
# \* Last modified Tue Mar 23 09:12:11 PDT 2021 by lucaswiman
# \* Created Tue Mar 23 08:57:57 PDT 2021 by lucaswiman
# ```
#
# See also:
# * https://github.com/tlaplus/PlusPy
# * https://pypi.org/project/tlaplus-jupyter/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Should have matchIndex in appendEntries RPC response (present in TLA+ spec).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
